# %%
import pandas as pd

# %%
M_food_prices = pd.read_csv("wfp_market_food_prices.csv", on_bad_lines='error')

# %%
M_food_prices.describe()
# Out:
#              adm0_id        adm1_id         mkt_id          cm_id  \
# count  612035.000000  612035.000000  612035.000000  612035.000000
# mean      142.686428   11254.992749     849.863812     158.700132
# std        56.403162   18634.362224     494.039910     119.280848
# min         1.000000       0.000000     101.000000      50.000000
# 25%       108.000000    1497.000000     422.000000      67.000000
# 50%       152.000000    1934.000000     892.000000     101.000000
# 75%       196.000000   21969.000000    1087.000000     227.000000
# max       238.000000  112869.000000    2094.000000     490.000000
#
#               cur_id          pt_id          um_id       mp_month  \
# count  612035.000000  612034.000000  612034.000000  612034.000000
# mean       54.460397      14.927718       9.690055       6.396525
# std        21.693574       0.286900      11.197979       3.436530
# min        23.000000      14.000000       5.000000       1.000000
# ...
